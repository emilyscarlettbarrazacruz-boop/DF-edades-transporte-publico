# %% [markdown]
# <a href="https://colab.research.google.com/github/emilyscarlettbarrazacruz-boop/DF-edades-transporte-publico/blob/main/DF_transporte_publico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad=float(input("ingresa tu edad"))

if edad < 12 or edad > 65:
    print("pagaras 12 pesos")

else:
    print("pagaras 5 pesos")
# Out:
# ingresa tu edad13
# pagaras 5 pesos

# %%
edad=float(input("ingresa tu edad"))

if edad < 12 or edad > 65:
    print("pagaras 12 pesos")

else:
    print("pagaras 5 pesos")
# Out:
# ingresa tu edad6
# pagaras 12 pesos

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/emilyscarlettbarrazacruz-boop/DF-edades-transporte-publico/refs/heads/main/Diagrama%20en%20blanco.png)
